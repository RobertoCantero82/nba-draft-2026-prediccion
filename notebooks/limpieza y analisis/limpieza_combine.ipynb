# %% [markdown]
# ## Importo librerías y cargo el dataset "combine_historico.csv"

# %%
import pandas as pd
import numpy as np

# cargo el dataset del combine
combine = pd.read_csv('../datos/raw/combine_historico.csv')

# %%
combine
# Out:
#       SEASON  PLAYER_ID FIRST_NAME  LAST_NAME       PLAYER_NAME POSITION  \
# 0       2000       2124      Malik      Allen       Malik Allen     PF-C
# 1       2000      12019     Harold  Arceneaux  Harold Arceneaux    SG-SF
# 2       2000      12020     Lamont     Barnes     Lamont Barnes     PF-C
# 3       2000      12131      Mario      Bland       Mario Bland       PF
# 4       2000       2056     Primoz     Brezec     Primoz Brezec        C
# ...      ...        ...        ...        ...               ...      ...
# 1868    2026    1642870      Milos       Uzan        Milos Uzan       PG
# 1869    2026    1643539      Henri    Veesaar     Henri Veesaar        C
# 1870    2026    1643413     Keaton     Wagler     Keaton Wagler       PG
# 1871    2026    1643410      Caleb     Wilson      Caleb Wilson       PF
# 1872    2026    1643537     Tounde  Yessoufou  Tounde Yessoufou       SG
#
#       HEIGHT_WO_SHOES HEIGHT_WO_SHOES_FT_IN  HEIGHT_W_SHOES  \
# 0               80.25             6' 8.25''             NaN
# 1               76.50              6' 4.5''             NaN
# 2               80.50              6' 8.5''             NaN
# 3               77.50              6' 5.5''             NaN
# 4               84.75             7' 0.75''             NaN
# ...               ...                   ...             ...
# 1868            75.00             6' 3.00''             NaN
# 1869            83.25            6' 11.25''             NaN
# 1870            77.00             6' 5.00''             NaN
# 1871            81.25             6' 9.25''             NaN
# 1872            76.25             6' 4.25''             NaN
#
#      HEIGHT_W_SHOES_FT_IN  ...  SPOT_NBA_BREAK_RIGHT  SPOT_NBA_CORNER_RIGHT  \
# 0                     NaN  ...                   NaN                    NaN
# 1                     NaN  ...                   NaN                    NaN
# 2                     NaN  ...                   NaN                    NaN
# 3                     NaN  ...                   NaN                    NaN
# 4                     NaN  ...                   NaN                    NaN
# ...                   ...  ...                   ...                    ...
# 1868                  NaN  ...                   NaN                    NaN
# 1869                  NaN  ...                   NaN                    NaN
# 1870                  NaN  ...                   NaN                    NaN
# 1871                  NaN  ...                   NaN                    NaN
# 1872                  NaN  ...                   NaN                    NaN
#
#      OFF_DRIB_FIFTEEN_BREAK_LEFT  OFF_DRIB_FIFTEEN_TOP_KEY  \
# 0                            NaN                       NaN
# 1                            NaN                       NaN
# 2                            NaN                       NaN
# 3                            NaN                       NaN
# 4                            NaN                       NaN
# ...                          ...                       ...
# 1868                         NaN                       NaN
# 1869                         NaN                       NaN
# 1870                         NaN                       NaN
# 1871                         NaN                       NaN
# 1872                         NaN                       NaN
#
#      OFF_DRIB_FIFTEEN_BREAK_RIGHT  OFF_DRIB_COLLEGE_BREAK_LEFT  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3                             NaN                          NaN
# 4                             NaN                          NaN
# ...                           ...                          ...
# 1868                          NaN                        24-30
# 1869                          NaN                        18-30
# 1870                          NaN                        25-30
# 1871                          NaN                        19-30
# 1872                          NaN                        16-30
#
#       OFF_DRIB_COLLEGE_TOP_KEY  OFF_DRIB_COLLEGE_BREAK_RIGHT  ON_MOVE_FIFTEEN  \
# 0                          NaN                           NaN              NaN
# 1                          NaN                           NaN              NaN
# 2                          NaN                           NaN              NaN
# 3                          NaN                           NaN              NaN
# 4                          NaN                           NaN              NaN
# ...                        ...                           ...              ...
# 1868                       NaN                           NaN              NaN
# 1869                       NaN                           NaN              NaN
# 1870                       NaN                           NaN              NaN
# 1871                       NaN                           NaN              NaN
# 1872                       NaN                           NaN              NaN
#
#       ON_MOVE_COLLEGE
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
# ...               ...
# 1868            13-25
# 1869            12-25
# 1870            12-25
# 1871            12-25
# 1872            10-25
#
# [1873 rows x 47 columns]

# %% [markdown]
# ## Empiezo con el dataframe "combine"

# %% [markdown]
# Busco a los jugadores españoles en el dataframe combine

# %%
# busco por nombre
print("=== ESPAÑOLES EN COMBINE 2026 ===")
espanoles = combine[
    (combine['SEASON'] == 2026) &
    (combine['PLAYER_NAME'].str.contains('Mara|Miller|Larrea', case=False, na=False))
]
print(espanoles[['PLAYER_NAME', 'POSITION', 'HEIGHT_WO_SHOES', 'WEIGHT', 'WINGSPAN', 'STANDING_REACH', 'MAX_VERTICAL_LEAP', 'LANE_AGILITY_TIME']].to_string())
# Out:
# === ESPAÑOLES EN COMBINE 2026 ===
#            PLAYER_NAME POSITION  HEIGHT_WO_SHOES  WEIGHT  WINGSPAN  STANDING_REACH  MAX_VERTICAL_LEAP  LANE_AGILITY_TIME
# 1818  Sergio De Larrea       PG              NaN     NaN       NaN             NaN                NaN                NaN
# 1837         Aday Mara        C             87.0   259.8     90.00           117.0               28.0              11.47
# 1839       Baba Miller       PF             82.5   208.2     85.75           111.0               34.5              10.71

# %% [markdown]
# Aquí ya tenemos el primer problema, con los datos de Sergio De Larrea que no están disponibles, ya que no ha participado en el Combine al estar jugando en Europa y no en la liga universitaria norteamericana. Busco sus datos y los relleno manualmente.

# %%
# corrijo a Sergio De Larrea con sus datos reales (fuentes externas)
# altura sin zapatillas: 198cm = 77.95 pulgadas
# peso: 174 lbs (79kg), envergadura: 202cm = 79.53 pulgadas
# alcance de pie: estimado ~255cm = 100.4 pulgadas
mask_sergio = combine['PLAYER_NAME'] == 'Sergio De Larrea'
combine.loc[mask_sergio, 'HEIGHT_WO_SHOES'] = 77.95
combine.loc[mask_sergio, 'WEIGHT']          = 174.2
combine.loc[mask_sergio, 'WINGSPAN']        = 79.53
combine.loc[mask_sergio, 'STANDING_REACH']  = 100.4

# compruebo que Sergio queda bien
print(combine[mask_sergio][['PLAYER_NAME','HEIGHT_WO_SHOES','WEIGHT','WINGSPAN','STANDING_REACH']].to_string())
# Out:
#            PLAYER_NAME  HEIGHT_WO_SHOES  WEIGHT  WINGSPAN  STANDING_REACH
# 1818  Sergio De Larrea            77.95   174.2     79.53           100.4

# %% [markdown]
# Miro el porcentaje de nulos que hay en las columnas del dataframe combine

# %%
# NaN por columna
print("\n=== NaN POR COLUMNA (%) ===")
miss = (combine.isnull().sum() / len(combine) * 100).sort_values(ascending=False)
print(miss[miss > 0].round(2).to_string())
# Out:
# === NaN POR COLUMNA (%) ===
# OFF_DRIB_COLLEGE_BREAK_RIGHT    98.34
# OFF_DRIB_COLLEGE_TOP_KEY        98.34
# SPOT_FIFTEEN_CORNER_LEFT        94.45
# SPOT_FIFTEEN_BREAK_RIGHT        94.34
# SPOT_FIFTEEN_BREAK_LEFT         94.34
# SPOT_FIFTEEN_TOP_KEY            94.34
# SPOT_FIFTEEN_CORNER_RIGHT       94.34
# SPOT_COLLEGE_BREAK_LEFT         90.87
# SPOT_COLLEGE_CORNER_RIGHT       90.87
# SPOT_COLLEGE_TOP_KEY            90.87
# SPOT_COLLEGE_BREAK_RIGHT        90.87
# ON_MOVE_FIFTEEN                 90.18
# OFF_DRIB_FIFTEEN_BREAK_RIGHT    89.27
# OFF_DRIB_FIFTEEN_BREAK_LEFT     89.27
# OFF_DRIB_FIFTEEN_TOP_KEY        89.27
# SPOT_NBA_CORNER_LEFT            86.55
# SPOT_NBA_BREAK_RIGHT            86.55
# SPOT_NBA_TOP_KEY                86.55
# SPOT_NBA_BREAK_LEFT             86.55
# SPOT_NBA_CORNER_RIGHT           86.55
# OFF_DRIB_COLLEGE_BREAK_LEFT     81.10
# ON_MOVE_COLLEGE                 80.25
# SPOT_COLLEGE_CORNER_LEFT        73.52
# MODIFIED_LANE_AGILITY_TIME      61.08
# HAND_WIDTH                      42.55
# HAND_LENGTH                     42.55
# BENCH_PRESS                     41.54
# HEIGHT_W_SHOES                  35.66
# HEIGHT_W_SHOES_FT_IN            35.66
# BODY_FAT_PCT                    31.87
# THREE_QUARTER_SPRINT            13.99
# LANE_AGILITY_TIME               13.99
# STANDING_VERTICAL_LEAP          13.67
# MAX_VERTICAL_LEAP               13.67
# WEIGHT                           3.31
# STANDING_REACH_FT_IN             3.31
# HEIGHT_WO_SHOES_FT_IN            3.26
# STANDING_REACH                   3.26
# WINGSPAN_FT_IN                   3.26
# WINGSPAN                         3.20
# HEIGHT_WO_SHOES                  3.20
# POSITION                         0.27

# %% [markdown]
# Opto por aligerar el dataframe, con lo que elimino las columnas con más de un 50 % de valores nulos y aquellas que sean redundantes. También elimino "PLAYER_ID", que no aporta valor al ser un identificador interno.

# %%
# 1. Identificamos columnas con más del 50% de nulos
cols_eliminar = [col for col in combine.columns if combine[col].isnull().mean() > 0.5]
combine = combine.drop(columns=cols_eliminar)
print(f"Columnas eliminadas por >50% NaN: {len(cols_eliminar)}")

# 2. Eliminamos las columnas de formato pies/pulgadas (redundantes)
cols_ft_in = [col for col in combine.columns if 'FT_IN' in col]
combine = combine.drop(columns=cols_ft_in)
print(f"Columnas redundantes eliminadas: {cols_ft_in}")

# 3. Eliminamos PLAYER_ID (identificador interno)
if 'PLAYER_ID' in combine.columns:
    combine = combine.drop(columns=['PLAYER_ID'])

print(f"Columnas restantes tras el filtrado: {combine.shape[1]}")
# Out:
# Columnas eliminadas por >50% NaN: 24
# Columnas redundantes eliminadas: ['HEIGHT_WO_SHOES_FT_IN', 'HEIGHT_W_SHOES_FT_IN', 'WINGSPAN_FT_IN', 'STANDING_REACH_FT_IN']
# Columnas restantes tras el filtrado: 18

# %% [markdown]
# Me queda tratar los NaN y algunas columnas con números que pueden dar problemas

# %%
# columnas físicas numéricas que quedan
cols_fisicas = ['HEIGHT_WO_SHOES', 'HEIGHT_W_SHOES', 'WEIGHT', 'WINGSPAN',
                'STANDING_REACH', 'BODY_FAT_PCT', 'HAND_LENGTH', 'HAND_WIDTH',
                'STANDING_VERTICAL_LEAP', 'MAX_VERTICAL_LEAP',
                'LANE_AGILITY_TIME', 'MODIFIED_LANE_AGILITY_TIME',
                'THREE_QUARTER_SPRINT', 'BENCH_PRESS']

# convierto a numérico por si hay algún valor corrupto
for col in cols_fisicas:
    if col in combine.columns:
        combine[col] = pd.to_numeric(combine[col], errors='coerce')

# imputo NaN con la mediana de cada columna
for col in cols_fisicas:
    if col in combine.columns:
        combine[col] = combine[col].fillna(combine[col].median())

# imputo POSITION con la moda
combine['POSITION'] = combine['POSITION'].fillna(combine['POSITION'].mode()[0])

# compruebo NaN restantes
print(f"\nNaN restantes: {combine.isnull().sum().sum()}")
print(f"\nShape final: {combine.shape}")
# Out:
# NaN restantes: 0
#
# Shape final: (1873, 18)

# %% [markdown]
# Guardo el dataframe listo para utilizar con modelos

# %%
# guardo el combine limpio en la carpeta de datos procesados
combine.to_csv('../datos/procesados/combine_final.csv', index=False)

# comprobación final con los tres españoles
print("=== DATASET COMBINE FINAL ===")
print(f"Shape: {combine.shape}")
print(f"\nLos tres españoles:")
espanoles = combine[combine['PLAYER_NAME'].isin(['Aday Mara', 'Baba Miller', 'Sergio De Larrea'])]
print(espanoles[['PLAYER_NAME', 'POSITION', 'HEIGHT_WO_SHOES', 'WEIGHT', 'WINGSPAN', 'STANDING_REACH', 'MAX_VERTICAL_LEAP', 'LANE_AGILITY_TIME']].to_string())
# Out:
# === DATASET COMBINE FINAL ===
# Shape: (1873, 18)
#
# Los tres españoles:
#            PLAYER_NAME POSITION  HEIGHT_WO_SHOES  WEIGHT  WINGSPAN  STANDING_REACH  MAX_VERTICAL_LEAP  LANE_AGILITY_TIME
# 1818  Sergio De Larrea       PG            77.95   174.2     79.53           100.4               34.5              11.30
# 1837         Aday Mara        C            87.00   259.8     90.00           117.0               28.0              11.47
# 1839       Baba Miller       PF            82.50   208.2     85.75           111.0               34.5              10.71
